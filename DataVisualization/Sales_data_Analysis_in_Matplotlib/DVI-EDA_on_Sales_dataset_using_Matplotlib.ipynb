# %% [markdown]
# <img src = "https://www.bits-pilani.ac.in/Uploads/Campus/BITS_university_logo.gif">

# %% [markdown]
# <h1><center>Work Integrated Learning Programmes Division<br>
# M.Tech (Data Science and Engineering)<br> Data Visualization And Interpretation (DSECL ZG555))<br>
# Second Semester, 2020-21
# </center></h1>
#
# <h2><center>Assignment 2 – PS7 [Weightage 13%]</center></h2>

# %% [markdown]
# ## Instructions
# <ol>
#   <li>Do not change the name of the data file that is shared with the problem statement.</li>
#   <li>If intermediate data files are created, retain in the present working directory and attach them during submission.</li>
#   <li>Retain the data file in the same directory as that of this workbook.</li>
#   <li>Retain the Visualizations that is produced in the file. Don't clear them away.</li>
#   <li>Submit only the .IPYNB file. Intermediate files to be attached as mentioned in (2).</li>
#     <li><b><div class="alert-warning">All the visuals should adhere to the visualization principles learnt in the Course and must be presentation ready.Most effective visuals would fetch maximum credits</div></b></li>
#     <li><b><div class="alert-warning">Submissions done via means other than CANVAS will strictly be NOT graded.</div></b></li>
#
#
#
#
# </ol>

# %% [markdown]
# <style>
# table {
#   font-family: arial, sans-serif;
#   border-collapse: collapse;
#   width: 100%;
# }
#
# td, th {
#   border: 1px solid #dddddd;
#   text-align: left;
#   padding: 8px;
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
#
# <h2>Group No: 147 </h2>
#
# <table>
#   <tr>
#     <th>Full Name</th>
#     <th>BITS ID</th>
#   </tr>
#   <tr>
#     <td>Ashutosh Kumar</td>
#     <td>2020FC04350</td>
#   </tr>
#   <tr>
#     <td>Rahul Paul</td>
#     <td>2020FC04341</td>
#   </tr>
#   <tr>
#     <td>Ashwini BR</td>
#     <td>2020FC04180</td>
#   </tr>
# </table>

# %% [markdown]
# <h1>Objective</h1>
# <h4>Perform EDA on the data set.</h4>

# %% [markdown]
# ##  Download and Prep the Data: 1 Mark

# %% [markdown]
# <h4>Import the libraries needed</h4>

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.ion()
matplotlib.interactive(True)

# %% [markdown]
# <h4> Load data and store in dataframe </h4>

# %%
sales = pd.read_csv("dvi-a2-ps7-data.csv")

# %% [markdown]
# <h4>Find out  what type of variable you are dealing with. This will help you find the right visualization method for that variable.</p>

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Invoice ID       1000 non-null   object
#  1   Branch           1000 non-null   object
#  2   City             1000 non-null   object
#  3   Customer type    1000 non-null   object
#  4   Gender           1000 non-null   object
#  5   Product line     1000 non-null   object
#  6   Unit price       1000 non-null   float64
#  7   Quantity         1000 non-null   int64
#  8   Total            1000 non-null   float64
#  9   Date             1000 non-null   object
#  10  Time             1000 non-null   object
#  11  Payment          1000 non-null   object
#  12  costofgoodssold  1000 non-null   float64
#  13  Rating           1000 non-null   float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 109.5+ KB

# %% [markdown]
# #### Display the summary statistics of the data.In a markdown cell below,explain your findings

# %%
sales.describe(include='object')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     173-50-1108      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#               Date   Time  Payment
# count         1000   1000     1000
# unique          89    506        3
# top     02-07-2019  14:42  Ewallet
# freq            20      7      345

# %%
sales.describe()
# Out:
#         Unit price     Quantity        Total  costofgoodssold      Rating
# count  1000.000000  1000.000000  1000.000000       1000.00000  1000.00000
# mean     55.672130     5.510000   322.966749        307.58738     6.97270
# std      26.494628     2.923431   245.885335        234.17651     1.71858
# min      10.080000     1.000000    10.678500         10.17000     4.00000
# 25%      32.875000     3.000000   124.422375        118.49750     5.50000
# 50%      55.230000     5.000000   253.848000        241.76000     7.00000
# 75%      77.935000     8.000000   471.350250        448.90500     8.50000
# max      99.960000    10.000000  1042.650000        993.00000    10.00000

# %% [markdown]
# #### Identify whether male/female spends more on 'Health and beauty'.Write the code below

# %%
mlExp = int(sales.loc[(sales['Gender'] == 'Male') & (sales['Product line'] == 'Health and beauty'), 'Total'].sum())
fmlExp = int(sales.loc[(sales['Gender'] == 'Female') & (sales['Product line'] == 'Health and beauty'), 'Total'].sum())
data = {'Gender':['Male', 'Female'], 'Total Expenses':[mlExp,fmlExp]}
dfml = pd.DataFrame(data)
plt.style.use('seaborn-white')
ax=dfml.plot(x="Gender",y="Total Expenses",kind = "bar",alpha=0.6,fontsize=15) 
plt.xticks(fontsize=14,rotation=0)
plt.yticks([])
plt.xlabel("Gender",size=17)
#plt.ylabel("Amount spent",size=15)
plt.title("Expenditure on 'Health and Beauty' by Gender",fontsize=18,y=1.1)


for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
    (p.get_x() + p.get_width() / 2., p.get_height()), 
    ha = 'center', va = 'center', 
    xytext = (0, 9), 
    textcoords = 'offset points')


for ax, spine in ax.spines.items():
    spine.set_visible(False)
    
plt.show()

# %% [markdown]
# #### Findings: <br>
# -  As can be seen from the visual, <br>
# 'Male' population spends more on "Health and Beauty" than the 'Female' population <br>
#
# #### Reason for selecting the chart type: <br>
# -  The histogram chart type is selected as it clearly compares and shows the difference in Total Expenses for the "Male" and "Female"Categories.
#
# #### Pre-attentive attributes used:
# -  Bar height
# -  Spatial position
#
# #### Gestalt principles used:
# -  Principle of Closure (No outer boundaries)
# -  Principle of Proximity (The values of "Amount spent" are indicated close to each bar)

# %% [markdown]
# # Visualisation Questions - 2 X 5 = 10 Marks

# %% [markdown]
# ### Question 1
# <h4>Check the distribution of the Price variable .<br><br>
#     Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual..<br>
#     2.The reason for selecting the chart type you did <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
fig = plt.figure(figsize=(15,12))
gs = fig.add_gridspec(2,2)
gs.update(wspace=0.3, hspace=0.3)
ax0 = fig.add_subplot(gs[0,0])
ax1 = fig.add_subplot(gs[1,:])
ax2 = fig.add_subplot(gs[0,1])

ax0.title.set_text('Scatter Plot')
ax0.title.set_size(18)
ax1.title.set_text('Histogram Plot')
ax1.title.set_size(18)
ax2.title.set_text('Box Plot')
ax2.title.set_size(18)

ax0.xaxis.label.set_size(16)
ax0.yaxis.label.set_size(16)
ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax0.set_xlim(0,100)

sns.scatterplot(ax=ax0,data=sales,y="Product line",x="Unit price")

axi=sns.boxplot(ax=ax2,data=sales,y="Unit price",color='cyan',linewidth=2.5)
axi.set_ylabel("Unit Price",size=15)
axi.tick_params(left = True, bottom = False)
for axi, spine in axi.spines.items():
    spine.set_visible(False)
    
axii=sns.histplot(sales["Unit price"],kde=True,ax=ax1,alpha=0.4) 
axii.set_xlabel("Unit price",size=17)
axii.set_ylabel("Frequency",size=17)
axii.axes.yaxis.set_ticklabels([])
patch_h = []    
for patch in axii.patches:
    reading = patch.get_height()
    patch_h.append(reading)
idx_tallest = np.argmax(patch_h)   
axii.patches[idx_tallest].set_facecolor('orange') 
m=sales["Unit price"].mean()
kdeline = axii.lines[0]
xs = kdeline.get_xdata()
ys = kdeline.get_ydata()
height = np.interp(m, xs, ys)
axii.vlines(m, 0, height, color='crimson', ls=':',linewidth=3.5)

for p in axii.patches:
    axii.annotate(format(p.get_height(), '.0f'), 
    (p.get_x() + p.get_width() / 2., p.get_height()), 
    ha = 'center', va = 'center', 
    xytext = (0, 9), 
    textcoords = 'offset points')
axii.text(m-2,-5, "Mean", size = 14, alpha = 0.85)
# Remove ticks and spines
axii.tick_params(left = False, bottom = False)
for axii, spine in axii.spines.items():
    spine.set_visible(False)

# %% [markdown]
# #### Findings: <br>
# As can be seen from the visual, <br>
# -  The "Unit price" is distributed across the whole Unit price range (10 to 100) for all the product lines. <br>
# -  There are more products in the Unit price range of 90-100
# -  The mean value of "Unit price is approximately around 55
# -  There are no outliers in the dataset values for this attribute
# -  The summary statistics are: Min value=10, 25%=30, mean=55, 75%=80, max value=100
#
# #### Reason for selecting the chart type: <br>
# -  The scatterplot chart type is selected as it clearly shows that the Unit price is distributed across all price ranges for all product lines.
# -  The box plot is used to visualise the statistical summary of the "Unit price" attribute.
# -  The distribution histplot shows the frequency of distribution and also the kde line to visualize the spread of "Unit price" values. <br>
# The mode value is highlighted in red.
#
# #### Pre-attentive attributes used:
# -  Curvature
# -  Hue
# -  Added marks
# -  Bar height
#
#
# #### Gestalt principles used:
# -  Principle of Closure (No or reduced outer boundaries)
# -  Principle of Proximity (The values of "Frequency" are indicated close to each bar)
# -  Principle of Similarity (dots in scatter plot and bars in histplot)
# -  Principle of Continuity (No axis lines in boxplot and histplot)

# %% [markdown]
# ### Question 2
# <h4>What does the distribution of customer rating looks like?Draw the mean,25th and 75th percentile on the plot.<br><br>
#     Write the python code in the below cell to create the appropriate visual to perform the above task .
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
fig = plt.figure(figsize=(15,12))
gs = fig.add_gridspec(2,2)
gs.update(wspace=0.3, hspace=0.3)
ax0 = fig.add_subplot(gs[0,0])
ax1 = fig.add_subplot(gs[0,1])
ax2 = fig.add_subplot(gs[1,:])

ax0.title.set_text('Distribution Plot')
ax0.title.set_size(18)
ax1.title.set_text('Histogram Plot')
ax1.title.set_size(18)
ax2.title.set_text('Detail Histogram Plot')
ax2.title.set_size(18)
ax2.xaxis.label.set_size(12)
for tick in ax2.xaxis.get_major_ticks():
                tick.label.set_fontsize(13) 
                tick.label.set_rotation('vertical')

sales["Rating"].plot(ax=ax0,kind = "hist", density = True,alpha=0.3, bins = 6)
sales["Rating"].plot(ax=ax0,kind="kde")
#ax0.tick_params(left = False, bottom = False)
ax0.set_ylabel("Frequency",size=17)
ax0.set_yticks([])
ax0.set_xlabel("Rating",size=15)

quant_25, quant_50, quant_75 = sales["Rating"].quantile(0.25), sales["Rating"].quantile(0.5), sales["Rating"].quantile(0.75)

quants = [ [quant_25, 0.8, 0.26], [quant_50, 1, 0.36],  [quant_75, 0.8, 0.46]]
for i in quants:
    ax0.axvline(i[0], alpha = i[1], ymax = i[2], linestyle = ":", linewidth=3.5,color='red')
ax0.text(quant_25-0.3,0.055, "25th", size = 13, alpha = 0.85)
ax0.text(quant_50-0.2, 0.075, "50th", size = 13, alpha = 1)
ax0.text(quant_75-.25, 0.09, "75th", size = 13, alpha = 0.85)

for ax0, spine in ax0.spines.items():
    spine.set_visible(False)  
#plt.show()


sns.set_style("white")


axi=sns.histplot(sales,x="Rating",binwidth=1,ax=ax1,alpha=0.4,color='g') 
patch_h = []    
for patch in axi.patches:
    reading = patch.get_height()
    patch_h.append(reading)
idx_tallest = np.argmax(patch_h)   
axi.patches[idx_tallest].set_facecolor('#a834a6') 
axi.set_yticks([])
axi.set_ylabel("Frequency",size=15)
axi.set_xlabel("Rating",size=15)
for p in axi.patches:
    axi.annotate(format(p.get_height(), '.0f'), 
        (p.get_x() + p.get_width() / 2., p.get_height()-15), 
        ha = 'center', va = 'center', 
        xytext = (0, 9), 
        textcoords = 'offset points',color='white')
axi.tick_params(left = False, bottom = False)
for axi, spine in axi.spines.items():
    spine.set_visible(False)   
    
groupedvalues=sales["Rating"].value_counts(ascending=False).reset_index()
pal = sns.color_palette("Blues_d", len(groupedvalues))
rank = groupedvalues["index"].argsort()
sns.set_style({'axes.facecolor':'white', 'grid.color': '.8', 'font.family':'Times New Roman'})
g=sns.barplot(x='index',y='Rating', data=groupedvalues, palette=np.array(pal[::-1])[rank],ax=ax2)
plt.xlabel("Rating",size=15)
plt.ylabel("Frequency",size=15)

for p in g.patches:
    g.annotate(int(p.get_height()), 
        (p.get_x() + p.get_width() / 2., p.get_height()), 
        ha = 'center', va = 'center', 
        xytext = (0, 9), 
        textcoords = 'offset points')
for g, spine in g.spines.items():
    spine.set_visible(False)

# %% [markdown]
# #### Findings: <br>
# As can be seen from the visual, <br>
# -  The "Rating" attribute ranges between 4 to 10
# -  The average rating is 7
# -  Maximum number of ratings are between 6 to 7
#
# #### Reason for selecting the chart type: <br>
# -  The 'Distribution plot' shows the frequency of distribution and also the kde line to visualize the spread of "Unit price" values. <br>
# The 25th, 50th and 75th lines are plotted in the same visual.
# -  The 'Histogram Plot' shows the distribution too and the bar with highest frequency (mode value) is highlighted in purple
# -  The 'Detail Histogram Plot' further shows the distribution of Rating values in a continuous range from 4 to 10.
#
# #### Pre-attentive attributes used:
# -  Curvature
# -  Hue
# -  Added marks
# -  Bar height
#
#
# #### Gestalt principles used:
# -  Principle of Closure (No or reduced outer boundaries)
# -  Principle of Proximity (The values of "Frequency" are indicated close to each bar)
# -  Principle of Similarity (bars in histplot)
# -  Principle of Continuity (No axis lines)

# %% [markdown]
# ### Question 3
# <h4>For each payment method,compare the product lines.Does any stand out?.<br><br>
#     Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
plt.figure(dpi=150)
sns.set_style('white')
g=sns.countplot(y='Product line', hue = "Payment", data = sales,palette='Set3',edgecolor="g") 
plt.ylabel('Product line')
plt.xlabel('Product Type Count')
plt.xticks([])
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.xlim((0, 80))

patch_h = []    
for patch in g.patches:
    reading = patch.get_width()
    patch_h.append(reading)
idx_tallest = np.argmax(patch_h)   
g.patches[idx_tallest].set(hatch='//')
g.patches[idx_tallest].set_edgecolor('black')
g.patches[idx_tallest].set_linewidth(2)
for p in g.patches:
    g.annotate(int(p.get_width()),((p.get_x() + p.get_width()+2), p.get_y()), xytext=(3, -8),
               fontsize=9,color='#004d00',textcoords='offset points', horizontalalignment='right')

for g, spine in g.spines.items():
    spine.set_visible(False)

# %% [markdown]
# #### Findings: <br>
# As can be seen from the visual, <br>
# -  The 'Cash' payment method significantly stands out for purchases of 'Electronic accessories' products. <br>
# It is also the highest across all payment methods. <br>
# The corresponding bar is enclosed and hatched in the visual.
#
# #### Reason for selecting the chart type: <br>
# -  The 'Histogram Plot' shows the frequency of Product type clearly across the product lines.
#
# #### Pre-attentive attributes used:
# -  Hue
# -  Added marks
# -  Bar height
#
#
# #### Gestalt principles used:
# -  Principle of Enclosure (Tallest bar highlighted with edges/enclosure)
# -  Principle of Closure (No or reduced outer boundaries)
# -  Principle of Proximity (The values of "Frequency" are indicated close to each bar)
# -  Principle of Similarity (bars in histplot)
# -  Principle of Continuity (No axis lines)

# %% [markdown]
# ### Question 4
# <h4>Identify,which is the most appropriate time(hour) to give online disounts?<br><br>
#     Write the python code in the below cell to create the appropriate visual(single visual) to perform the above task .(Prep the data as necessary)
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
#https://www.vendhq.com/blog/how-to-discount-in-retail/
sns.set_style('white')
sales['Time'] = pd.to_datetime(sales['Time'])
sales['Hour'] = (sales['Time']).dt.hour
df1 = sales[["Hour","Quantity","Total"]].copy()
df2 = df1.groupby(['Hour']).sum()
df3 = df1.groupby(['Hour']).count()
df2['Invoice Count'] = df3[["Quantity"]].copy()
df_norm = df2.copy()
#plt.style.use('classic')
# apply min-max scaling
for column in df_norm.columns:
        df_norm[column] = (df_norm[column] - df_norm[column].min()) / (df_norm[column].max() - df_norm[column].min())
dnp = df_norm.reset_index()
plt.figure(figsize=(12,6))

ax=sns.lineplot(data=df_norm,markers=True, dashes=False,linewidth=2,markersize=10)
plt.legend(loc = 'upper left',fontsize = 14)

ax.set_xlabel("Hour of the day",fontsize = 14)
ax.set_ylabel("",fontsize = 14)
plt.yticks([])
plt.ylim((0,1.2))
plt.xticks(dnp['Hour'])
plt.arrow(19.1, 1.01, 0.2, 0.05, width = 0.025)
plt.title("Sales By Hour (Min-Max Scaled)",size=16)
ax.text(19, 1.1, "Highest Sale time is in between 7pm - 8pm",
        horizontalalignment='left', size='medium', color='black', weight='semibold')
for ax, spine in ax.spines.items():
    spine.set_visible(False)  
plt.show()

# %% [markdown]
# #### Findings: <br>
# As can be seen from the visual, <br>
# -  The Quantity, Total and Invoice count are all maximum at the 19:00 hour.
#
# #### Reason for selecting the chart type: <br>
# -  The 'Invoice Count','Quantity' and 'Total' columns are min-max scaled and the obtained values are plotted in a line graph to observe their trend by Hour. The line graph visual shows the variations in the attribute hour by hour.<br>
# As 'Hour' is continuous and other attributes plotted are categorical data. Line plot suits the requirement.
#
# #### Pre-attentive attributes used:
# -  Spatial Position
# -  Added marks
# -  Hue
#
#
# #### Gestalt principles used:
# -  Principle of Closure (No or reduced outer boundaries)
# -  Principle of Connectivity (Markers by hours connected with lines)
# -  Principle of Proximity (The values of markers are indicated close to each bar)
# -  Principle of Similarity (lines in lineplot)
# -  Principle of Continuity (No axis lines)

# %% [markdown]
# ### Question 5

# %% [markdown]
# <h4>Which product line is more profitable?<br><br>
#     Write the python code in the below cell to create the appropriate visual(single visual) to perform the above task .(Prep the data as necessary)
# <h4>Answer in markdown cells below the visual <br><br>
#     1.Summarise your findings from the visual.<br>
#     2.The reason for selecting the chart type you did <br>
#     3.Mention the pre-attentive attributes used.(atleast 2)<br>
#     4.Mention the gestalt principles used.(atleast 2)<br>

# %%
plt.figure()
plt.rcParams["figure.figsize"] = (9.0, 6.0)
gr = Product_Profit.plot(x="Product line",y="Profit",kind = "barh",legend=None)
maxV=(Product_Profit['Profit'].max()//100)*100+200
minV=(Product_Profit['Profit'].min()//100)*100-500
#maxV=(Product_Profit['Profit'].max()//100)*100+100
#minV=((Product_Profit['Profit'].mean()-Product_Profit['Profit'].min())//100)*100
plt.xlabel('Profit',fontsize=14)
plt.ylabel('Product Line',fontsize=14)
plt.rcParams["figure.figsize"] = (8.0, 6.0)
plt.yticks(size=13)
patch_h = []    
for patch in gr.patches:
    reading = patch.get_width()
    patch_h.append(reading)
idx_tallest = np.argmax(patch_h)   
#gr.patches[idx_tallest].set(hatch='/')
gr.patches[idx_tallest].set_facecolor('orange')
gr.patches[idx_tallest].set_edgecolor('white')
gr.patches[idx_tallest].set_linewidth(2)
for p in gr.patches:
    gr.annotate(int(p.get_width()),((p.get_x() + p.get_width()+55), p.get_y()+0.2), xytext=(1, 0),
               fontsize=12,color='#004d00',textcoords='offset points', horizontalalignment='right')
for pos in ['right', 'top']:
    plt.gca().spines[pos].set_visible(False)
plt.xlim((minV,maxV))
plt.xticks([])
for gr, spine in gr.spines.items():
    spine.set_visible(False)
plt.show()

# %% [markdown]
# #### Findings: <br>
# As can be seen from the visual, <br>
# -  The Profit is the highest for "Food and Beverages" product line.<br>
# "Fashion accessories" and "Electronic accessories" are having the next best profits.
#
# #### Reason for selecting the chart type: <br>
# -  The width of the bar graph very clearly compares and visualizes the profits across the different product lines.
# The highest value is highlighted in orange in the above graph
#
# #### Pre-attentive attributes used:
# -  Spatial Position
# -  Bar width
# -  Hue
#
#
# #### Gestalt principles used:
# -  Principle of Closure (No or reduced outer boundaries)
# -  Principle of Proximity (The values of "Profit" are indicated close to each bar)
# -  Principle of Similarity (bar colors)
# -  Principle of Continuity (No axis lines)

# %% [markdown]
# # Group's choice-2 Marks
#
# #### Frame 1 (more) question which will help in the EDA(Exploratory Data Analysis) of the given data set and answer the same using the best visual.
#
#  1. Write the question in a markdown cell
#  2. Below the question,in a coding cell,write the python code to create the visual to answer the question
#
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    2.The reason for selecting the chart type you did <br>
#    3.Mention the pre-attentive attributes used.(atleast 2)<br>
#    4.Mention the gestalt principles used.(atleast 2)<br>

# %% [markdown]
# ### Question: Which city has the most high spending customers?

# %%
sales['month'] = pd.DatetimeIndex(sales['Date']).month

# %%
import matplotlib.patches as patch
fig=plt.figure(figsize=(15,10))
plt.xticks(size=14)
plt.xlabel('Product',size=15)
plt.yticks(size=13)
plt.ylabel('Total',size=15)

#ax1=fig.add_subplot(221)
ax1=sns.stripplot(data=sales, x="Product line", y="Total", hue="City",jitter=True,size=6)
rect=patch.Rectangle((1.6,980),3.75,80,facecolor='#dcdcdc',edgecolor='purple',linewidth=4)
ax1.add_patch(rect)

plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.,fontsize=15)
for ax1, spine in ax1.spines.items():
    spine.set_visible(False)

# %% [markdown]
# #### Findings: <br>
# As can be seen from the visual, <br>
# -  The highest number and Total Sales have been in the product lines of "Home and lifestyle" and "Fashion accessories".<br>
# -  There is one high Total transaction in the product lines of "Sports and Travel" and "Food and Beverages"
# -  The City of "Naypyitaw" is observed to have the highest Sales across all these product lines. This indicates that this city has the most high spending customer and thus corresponding marketing strategies can be designed.
# #### Reason for selecting the chart type: <br>
# -  The strip plot used, not only shows the distribution of Total Sales of each product across cities but also shows the frequency and highest values. The highest value range are enclosed in the rectangle in the visual.
# -  As the exact frequency values or Total Sales is not of significance, the strip plot serves the purpose.
#
# #### Pre-attentive attributes used:
# -  Line Thickness
# -  Spatial Position
# -  Added marks
# -  Hue
#
#
# #### Gestalt principles used:
# -  Principle of Closure (No or reduced outer boundaries)
# -  Principle of Enclosure (Highest value range enclosed in rectangle)
# -  Principle of Proximity (The dots in the plot for each product are close to each other)
# -  Principle of Similarity (All dots indicating Sales of a particular city are of same color)
# -  Principle of Continuity (No axis lines)

# %% [markdown]
# <h1><center> ************ END OF ASSIGNMENT ****************</center></h1>
